# %%
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import seaborn as sns

# %%
attr = pd.read_csv("employee_attrition_dataset.csv")

# %%
attr
# Out:
#    EmployeeID  Age  Gender Department               JobRole  \
# 0         101   28    Male      Sales       Sales Executive
# 1         102   35  Female         HR         HR Specialist
# 2         103   41    Male        R&D        Data Scientist
# 3         104   29  Female      Sales  Sales Representative
# 4         105   50    Male    Finance     Financial Analyst
# 5         106   26  Female        R&D        Lab Technician
# 6         107   33    Male         IT     Software Engineer
# 7         108   30  Female        R&D    Research Scientist
# 8         109   45    Male    Finance            Accountant
# 9         110   38  Female      Sales       Sales Executive
#
#                            Education  JobSatisfaction MaritalStatus  \
# 0            Business Administration                4        Single
# 1          Human Resource Management                3       Married
# 2  Computer Science / Data Analytics                2       Married
# 3                  Marketing & Sales                4        Single
# 4                Finance / Economics                3       Married
# 5                      Biotechnology                1        Single
# 6               Computer Engineering                2       Married
# 7                      Life Sciences                3        Single
# 8              Commerce / Accounting                4       Married
# 9            Business Administration                2      Divorced
#
#    YearsAtCompany  MonthlyIncome OverTime  PerformanceRating Attrition
# 0               2          32000      Yes                  3       Yes
# 1               7          42000       No                  4        No
# 2              10          75000      Yes                  3        No
# 3               3          28000      Yes                  2       Yes
# 4              20          88000       No                  4        No
# 5               1          25000      Yes                  3       Yes
# 6               5          62000       No                  3        No
# 7               4          40000      Yes                  3       Yes
# 8              15          56000       No                  4        No
# 9               8          46000       No                  3        No

# %%
attr.shape
# Out:
# (10, 13)

# %%
attr.isnull()
# Out:
#    EmployeeID    Age  Gender  Department  JobRole  Education  JobSatisfaction  \
# 0       False  False   False       False    False      False            False
# 1       False  False   False       False    False      False            False
# 2       False  False   False       False    False      False            False
# 3       False  False   False       False    False      False            False
# 4       False  False   False       False    False      False            False
# 5       False  False   False       False    False      False            False
# 6       False  False   False       False    False      False            False
# 7       False  False   False       False    False      False            False
# 8       False  False   False       False    False      False            False
# 9       False  False   False       False    False      False            False
#
#    MaritalStatus  YearsAtCompany  MonthlyIncome  OverTime  PerformanceRating  \
# 0          False           False          False     False              False
# 1          False           False          False     False              False
# 2          False           False          False     False              False
# 3          False           False          False     False              False
# 4          False           False          False     False              False
# 5          False           False          False     False              False
# 6          False           False          False     False              False
# 7          False           False          False     False              False
# 8          False           False          False     False              False
# 9          False           False          False     False              False
#
#    Attrition
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False

# %%
attr.isnull().sum()
# Out:
# EmployeeID           0
# Age                  0
# Gender               0
# Department           0
# JobRole              0
# Education            0
# JobSatisfaction      0
# MaritalStatus        0
# YearsAtCompany       0
# MonthlyIncome        0
# OverTime             0
# PerformanceRating    0
# Attrition            0
# dtype: int64

# %%
attr.describe()
# Out:
#        EmployeeID        Age  JobSatisfaction  YearsAtCompany  MonthlyIncome  \
# count    10.00000  10.000000        10.000000       10.000000      10.000000
# mean    105.50000  35.500000         2.800000        7.500000   49400.000000
# std       3.02765   7.905694         1.032796        6.059886   20705.340159
# min     101.00000  26.000000         1.000000        1.000000   25000.000000
# 25%     103.25000  29.250000         2.000000        3.250000   34000.000000
# 50%     105.50000  34.000000         3.000000        6.000000   44000.000000
# 75%     107.75000  40.250000         3.750000        9.500000   60500.000000
# max     110.00000  50.000000         4.000000       20.000000   88000.000000
#
#        PerformanceRating
# count          10.000000
# mean            3.200000
# std             0.632456
# min             2.000000
# 25%             3.000000
# 50%             3.000000
# 75%             3.750000
# max             4.000000

# %%
num = attr.select_dtypes(include=np.number).columns
len(num)
# Out:
# 6

# %%
for i in num:
 print("The no.of unique values in",i,"are: ",attr.loc[:,i].nunique())
# Out:
# The no.of unique values in EmployeeID are:  10
# The no.of unique values in Age are:  10
# The no.of unique values in JobSatisfaction are:  4
# The no.of unique values in YearsAtCompany are:  10
# The no.of unique values in MonthlyIncome are:  10
# The no.of unique values in PerformanceRating are:  3

# %%
attr.head()
# Out:
#    EmployeeID  Age  Gender Department               JobRole  \
# 0         101   28    Male      Sales       Sales Executive
# 1         102   35  Female         HR         HR Specialist
# 2         103   41    Male        R&D        Data Scientist
# 3         104   29  Female      Sales  Sales Representative
# 4         105   50    Male    Finance     Financial Analyst
#
#                            Education  JobSatisfaction MaritalStatus  \
# 0            Business Administration                4        Single
# 1          Human Resource Management                3       Married
# 2  Computer Science / Data Analytics                2       Married
# 3                  Marketing & Sales                4        Single
# 4                Finance / Economics                3       Married
#
#    YearsAtCompany  MonthlyIncome OverTime  PerformanceRating Attrition
# 0               2          32000      Yes                  3       Yes
# 1               7          42000       No                  4        No
# 2              10          75000      Yes                  3        No
# 3               3          28000      Yes                  2       Yes
# 4              20          88000       No                  4        No

# %%
attr.tail()
# Out:
#    EmployeeID  Age  Gender Department             JobRole  \
# 5         106   26  Female        R&D      Lab Technician
# 6         107   33    Male         IT   Software Engineer
# 7         108   30  Female        R&D  Research Scientist
# 8         109   45    Male    Finance          Accountant
# 9         110   38  Female      Sales     Sales Executive
#
#                  Education  JobSatisfaction MaritalStatus  YearsAtCompany  \
# 5            Biotechnology                1        Single               1
# 6     Computer Engineering                2       Married               5
# 7            Life Sciences                3        Single               4
# 8    Commerce / Accounting                4       Married              15
# 9  Business Administration                2      Divorced               8
#
#    MonthlyIncome OverTime  PerformanceRating Attrition
# 5          25000      Yes                  3       Yes
# 6          62000       No                  3        No
# 7          40000      Yes                  3       Yes
# 8          56000       No                  4        No
# 9          46000       No                  3        No

# %%
attr.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
attr.duplicated().value_counts()
# Out:
# False    10
# Name: count, dtype: int64

# %%
attr.nunique()
# Out:
# EmployeeID           10
# Age                  10
# Gender                2
# Department            5
# JobRole               9
# Education             9
# JobSatisfaction       4
# MaritalStatus         3
# YearsAtCompany       10
# MonthlyIncome        10
# OverTime              2
# PerformanceRating     3
# Attrition             2
# dtype: int64

# %%
att_count=pd.DataFrame(attr['Attrition'].value_counts())
att_count
# Out:
#            count
# Attrition
# No             6
# Yes            4

# %%
plt.pie(att_count["count"],labels=['No','Yes'],autopct='%.1f%%', explode=(0.1,0))
plt.show()

# %%
attr["Age"].nunique()
# Out:
# 10

# %%
attr.hist(column="Age",
 grid=False,
 figsize=(6,4),
 color="indigo",
 edgecolor="black",
 bins=12)
plt.xlabel("Age values",fontsize=12)
plt.ylabel("frequency of emp",fontsize=12)
plt.title("Histogram of Age",fontsize=16)
plt.show()

# %%
attr['Age'].value_counts().plot(kind='bar', figsize=(15,4), color="coral")
plt.xlabel("Age groups", fontsize=12)
plt.ylabel("Count of people", fontsize=12)
plt.title("Age of the employees", fontsize=16)
plt.show()

# %%
t = pd.crosstab(attr.Age,columns = attr.Attrition)
t
# Out:
# Attrition  No  Yes
# Age
# 26          0    1
# 28          0    1
# 29          0    1
# 30          0    1
# 33          1    0
# 35          1    0
# 38          1    0
# 41          1    0
# 45          1    0
# 50          1    0

# %%
plt.subplots (figsize=(15,4))
sns.countplot (x='Age', hue='Attrition', data= attr, palette = 'colorblind')
plt.show()

# %%
attr.boxplot(column = 'Age', by = 'Attrition', vert= False)
plt.show()

# %%
attr.MonthlyIncome.describe()
# Out:
# count       10.000000
# mean     49400.000000
# std      20705.340159
# min      25000.000000
# 25%      34000.000000
# 50%      44000.000000
# 75%      60500.000000
# max      88000.000000
# Name: MonthlyIncome, dtype: float64

# %%
attr["MonthlyIncome"].nunique()
# Out:
# 10

# %%
sns.distplot(attr['MonthlyIncome'])
plt.show()

# %%
p_attr = attr.loc[attr['Attrition'] == "Yes"]
n_attr = attr.loc[attr['Attrition'] == "No"]

# %%
sns.distplot(n_attr['MonthlyIncome'], label='Negative attrition')
sns.distplot(p_attr['MonthlyIncome'], label='positive attrition')
plt.show()

# %%
sns.catplot(x="Attrition",y="MonthlyIncome",kind="box",data=attr)
plt.title("Box plot grouped by Attrition")
plt.show()

# %%
sns.catplot(x="MaritalStatus",y="MonthlyIncome",hue="Attrition" ,kind="boxen", data=attr)
plt.show()

# %%
attr.plot.scatter(x = 'MonthlyIncome', y = 'Age',
 color = 'sandybrown', title = 'MonthlyIncome vs Age')
plt.show()

# %%
sns.violinplot(x ="JobSatisfaction", y ="MonthlyIncome", hue ="Attrition",
data = attr, split = True)
plt.show()

# %%
attr["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    3
# 3    3
# 2    3
# 1    1
# Name: count, dtype: int64

# %%
sns.countplot(attr["JobSatisfaction"])
plt.xticks(rotation=90)
plt.show()

# %%
labels = ['4', '3','1','2']
plt.pie(attr.JobSatisfaction.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
sns.relplot(x="JobSatisfaction",y="MonthlyIncome",hue="Attrition",kind="line", data=attr)
plt.show()

# %%
attr["Department"].value_counts()
# Out:
# Department
# Sales      3
# R&D        3
# Finance    2
# HR         1
# IT         1
# Name: count, dtype: int64

# %%
labels = attr.Department.value_counts().index
plt.pie(attr.Department.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
t3 = pd.crosstab(attr.Department,columns = attr.Attrition)
t3
# Out:
# Attrition   No  Yes
# Department
# Finance      2    0
# HR           1    0
# IT           1    0
# R&D          1    2
# Sales        1    2

# %%
attr = attr.replace("Yes", 1)

# %%
attr = attr.replace("No", 0)

# %%
attr.groupby('Department')['Attrition'].mean()
# Out:
# Department
# Finance    0.000000
# HR         0.000000
# IT         0.000000
# R&D        0.666667
# Sales      0.666667
# Name: Attrition, dtype: float64

# %%
sns.catplot(x="Department",y="Attrition" ,hue="MaritalStatus",kind="bar",data=attr)
plt.show()

# %%
sns.catplot(x="Department",y="Attrition" ,col="MaritalStatus",kind="bar",data=attr)
plt.show()

# %%
sns.catplot(x="Department",y="MonthlyIncome" ,hue="Attrition",kind="box",data=attr)
plt.show()

# %%
sns.catplot(x="Department",y="Age" ,kind="box",data=attr)
plt.show()

# %%
tab=pd.crosstab(attr["Department"],attr["Attrition"],normalize='index')*100
tab.plot(kind="bar")
plt.show()
print(tab)
# Out:
# Attrition            0          1
# Department
# Finance     100.000000   0.000000
# HR          100.000000   0.000000
# IT          100.000000   0.000000
# R&D          33.333333  66.666667
# Sales        33.333333  66.666667

# %%
attr["Education"].nunique()
# Out:
# 9

# %%
attr["Education"].value_counts()
# Out:
# Education
# Business Administration              2
# Human Resource Management            1
# Computer Science / Data Analytics    1
# Marketing & Sales                    1
# Finance / Economics                  1
# Biotechnology                        1
# Computer Engineering                 1
# Life Sciences                        1
# Commerce / Accounting                1
# Name: count, dtype: int64

# %%
attr["Education"].value_counts().plot(kind="barh",figsize=(8,4))
plt.show()

# %%
labels = attr.Education.value_counts().index
plt.pie(attr.Education.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
t4 = pd.crosstab(attr.Education,columns = attr.Attrition)
t4
# Out:
# Attrition                          0  1
# Education
# Biotechnology                      0  1
# Business Administration            1  1
# Commerce / Accounting              1  0
# Computer Engineering               1  0
# Computer Science / Data Analytics  1  0
# Finance / Economics                1  0
# Human Resource Management          1  0
# Life Sciences                      0  1
# Marketing & Sales                  0  1

# %%
tab=pd.crosstab(attr["Education"],attr["Attrition"],normalize='index')*10
tab.plot(kind="bar")
plt.show()
print(tab)
# Out:
# Attrition                             0     1
# Education
# Biotechnology                       0.0  10.0
# Business Administration             5.0   5.0
# Commerce / Accounting              10.0   0.0
# Computer Engineering               10.0   0.0
# Computer Science / Data Analytics  10.0   0.0
# Finance / Economics                10.0   0.0
# Human Resource Management          10.0   0.0
# Life Sciences                       0.0  10.0
# Marketing & Sales                   0.0  10.0

# %%
attr.groupby('Education').MonthlyIncome.mean()
# Out:
# Education
# Biotechnology                        25000.0
# Business Administration              39000.0
# Commerce / Accounting                56000.0
# Computer Engineering                 62000.0
# Computer Science / Data Analytics    75000.0
# Finance / Economics                  88000.0
# Human Resource Management            42000.0
# Life Sciences                        40000.0
# Marketing & Sales                    28000.0
# Name: MonthlyIncome, dtype: float64

# %%
sns.violinplot(x ="Education", y ="MonthlyIncome", hue ="Attrition",
data = attr, split = True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.relplot(x="Age",y="MonthlyIncome",hue="Attrition",col="MaritalStatus",data=attr)
plt.show()

# %%
attr["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    3
# 3    3
# 2    3
# 1    1
# Name: count, dtype: int64

# %%
attr["JobSatisfaction"].value_counts().plot(kind="bar",figsize=(4,6))
plt.xlabel("JobSatisfaction", fontsize=12)
plt.ylabel("Count of employees", fontsize=12)
plt.title("Bar plot on category JobSatisfaction", fontsize=16)
plt.show()

# %%
labels = ['3', '4', '2','1']
plt.pie(attr.JobSatisfaction.value_counts(), labels=labels, autopct='%1.1f%%')
plt.show()

# %%
t5 = pd.crosstab(attr.JobSatisfaction,columns = attr.Attrition)
t5
# Out:
# Attrition        0  1
# JobSatisfaction
# 1                0  1
# 2                3  0
# 3                2  1
# 4                1  2

# %%
tab = pd.crosstab(attr["JobSatisfaction"],attr["Attrition"],normalize='index')*100
print(tab)
tab.plot(kind='bar')
plt.show()
# Out:
# Attrition                 0           1
# JobSatisfaction
# 1                  0.000000  100.000000
# 2                100.000000    0.000000
# 3                 66.666667   33.333333
# 4                 33.333333   66.666667

# %%
plt.subplots (figsize=(22,8))
sns.countplot (x='Age', hue='JobSatisfaction', data= attr, palette = 'viridis')
plt.show()

# %%
sns.relplot(x="JobSatisfaction",y="MonthlyIncome",hue="Attrition",kind="line", data=attr)
plt.show()

# %%
attr["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     5
# Single      4
# Divorced    1
# Name: count, dtype: int64

# %%
labels = ['Married', 'Single','Divorced']
plt.pie(attr.MaritalStatus.value_counts(), labels=labels, autopct='%.1f%%')
plt.show()

# %%
attr['MaritalStatus'].value_counts().plot(kind='barh', figsize=(6,4), color="coral")
plt.xlabel("Count of people", fontsize=12)
plt.ylabel("MaritalStatus", fontsize=12)
plt.show()

# %%
attr.groupby('MaritalStatus').Attrition.mean()
# Out:
# MaritalStatus
# Divorced    0.0
# Married     0.0
# Single      1.0
# Name: Attrition, dtype: float64

# %%
tab = pd.crosstab(attr["MaritalStatus"],attr["Attrition"],normalize='index')*1
tab.plot(kind='bar')
plt.show()

# %%
attr.YearsAtCompany.describe()
# Out:
# count    10.000000
# mean      7.500000
# std       6.059886
# min       1.000000
# 25%       3.250000
# 50%       6.000000
# 75%       9.500000
# max      20.000000
# Name: YearsAtCompany, dtype: float64

# %%
attr['YearsAtCompany'].value_counts().plot(kind='bar', figsize=(19,4), color='skyblue')
plt.xlabel("Years At Company", fontsize=12)
plt.ylabel("Count of Employees", fontsize=12)
plt.show()

# %%
sns.relplot(x="MonthlyIncome",y="Age",hue="MaritalStatus",data=attr)
plt.show()

# %%
sns.relplot(x="YearsAtCompany",y="Age",hue="Attrition",col="MaritalStatus",data=attr)
plt.show()

# %%
numerical_attr = attr.select_dtypes(include=np.number)
display(numerical_attr.corr())
# Out:
#                    EmployeeID       Age  JobSatisfaction  YearsAtCompany  \
# EmployeeID           1.000000  0.215856    -2.487342e-01        0.202877
# Age                  0.215856  1.000000     1.224745e-01        0.986853
# JobSatisfaction     -0.248734  0.122474     1.000000e+00        0.177533
# YearsAtCompany       0.202877  0.986853     1.775328e-01        1.000000
# MonthlyIncome        0.077987  0.868851    -9.456537e-02        0.841268
# OverTime            -0.382971 -0.626667    -2.266233e-17       -0.608811
# PerformanceRating    0.058026  0.666667     6.804138e-02        0.695784
# Attrition           -0.213201 -0.789280     1.666667e-01       -0.710131
#
#                    MonthlyIncome      OverTime  PerformanceRating  Attrition
# EmployeeID              0.077987 -3.829708e-01           0.058026  -0.213201
# Age                     0.868851 -6.266667e-01           0.666667  -0.789280
# JobSatisfaction        -0.094565 -2.266233e-17           0.068041   0.166667
# YearsAtCompany          0.841268 -6.088108e-01           0.695784  -0.710131
# MonthlyIncome           1.000000 -4.785466e-01           0.502304  -0.754445
# OverTime               -0.478547  1.000000e+00          -0.666667   0.816497
# PerformanceRating       0.502304 -6.666667e-01           1.000000  -0.612372
# Attrition              -0.754445  8.164966e-01          -0.612372   1.000000

# %%
sns.heatmap(numerical_attr.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize = (14,14))
sns.heatmap(numerical_attr.corr(), annot=True, cmap='coolwarm') ###heatmap
plt.show()

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(attr, title="Pandas Profiling Report")
profile
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]
#  23%|██▎       | 3/13 [00:00<00:02,  3.72it/s]
# 100%|██████████| 13/13 [00:01<00:00, 12.63it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-10-22 17:34:46.699783&quot; name=date&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...
